# %% [markdown]
# ### Below are my ideas of the projects

# %% [markdown]
# ### 1. Creating of an online bookstore Inventory System
# This will entail:
# * Analyzing what books are available
# * Number of copies of the books avilable
# * The most selling books
# * Revenue being made

# %% [markdown]
# #### 2. Creating an account receivable and payable tracker
# This will entail :
# * Tracking our receivables( Who owes us money )
# * tracking ou rpayables ( How much do we owe others)
# * payments deadline
# * Analyze which invoices are overdue
# * Intrest to any late payment
# * Organization cash position

# %% [markdown]
# ##### 3. Automated Accounting System
# This will Entail :
# * Recording finnacial transactions
# * Posting the transaction to ledger accounts
# * Generating financial statements

# %% [markdown]
# ##### 4. Financial Statement analyzer
# This will entail :
# * Reading financial statement
# * cleaning and validating data
# * calculating financial ratios
# * produce reports
# * comparing organizational performance with other companies
